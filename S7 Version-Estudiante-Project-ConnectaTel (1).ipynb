# %% [markdown]
# # Análisis ConnectaTel
#
# Como **analista de datos**, tu objetivo es evaluar el **comportamiento de los clientes** de una empresa de telecomunicaciones en Latinoamérica, ConnectaTel.
#
# Trabajaremos con información registrada **hasta el año 2024**, lo cual permitirá analizar el comportamiento del negocio dentro de ese periodo.
#
# Para ello trabajarás con tres datasets:
#
# - **plans.csv** → información de los planes actuales (precio, minutos incluidos, GB incluidos, costo por extra)
# - **users.csv** → información de los clientes (edad, ciudad, fecha de registro, plan, churn)
# - **usage.csv** → detalle del **uso real** de los servicios (llamadas y mensajes)
#
# Deberás **explorar**, **limpiar** y **analizar** estos datos para construir un **perfil estadístico** de los clientes, detectar **comportamientos atípicos** y crear **segmentos de clientes**.
#
# Este análisis te permitirá **identificar patrones de consumo**, **diseñar estrategias de retención** y **sugerir mejoras en los planes** ofrecidos por la empresa.
#
# > 💡 Antes de empezar, recuerda pensar de forma **programática**: ¿qué pasos necesitas? ¿En qué orden? ¿Qué quieres medir y por qué?

# %% [markdown]
# ---
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de los tres datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯 Objetivo:**
# Tener los **3 datasets listos en memoria**, entender su contenido y realizar una revisión preliminar.
#
# **Instrucciones:**
# - Importa las librerías necesarias (por ejemplo `pandas`, `seaborn`, `matplotlib.pyplot`)
# - Carga los archivos CSV usando `pd.read_csv()`:
#   - **`/datasets/plans.csv`**
#   - **`/datasets/users_latam.csv`**
#   - **`/datasets/usage.csv`**
# - Guarda los DataFrames en las variables: `plans`, `users`, `usage`.
# - Muestra las primeras filas de cada DataFrame usando `.head()`.

# %%
# importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
plans = pd.read_csv('/datasets/plans.csv')
users = pd.read_csv("/datasets/users_latam.csv")#completa el código
usage = pd.read_csv("/datasets/usage.csv")#completa el código

# %%
# mostrar las primeras 5 filas de plans
plans.head()
# Out:
#   plan_name  messages_included  gb_per_month  minutes_included  \
# 0    Basico                100             5               100
# 1   Premium                500            20               600
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# 0               12         1.2             0.08            0.10
# 1               25         1.0             0.05            0.07

# %%
# mostrar las primeras 5 filas de users
users.head()
# Out:
#    user_id first_name last_name  age      city                       reg_date  \
# 0    10000     Carlos    Garcia   38  Medellín  2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres   53         ?  2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez   57      CDMX  2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez   69    Bogotá  2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres   63       GDL  2022-01-02 02:17:11.657914478
#
#       plan churn_date
# 0   Basico        NaN
# 1   Basico        NaN
# 2   Basico        NaN
# 3  Premium        NaN
# 4   Basico        NaN

# %%
# mostrar las primeras 5 filas de usage
usage.head()
# Out:
#    id  user_id  type                           date  duration  length
# 0   1    10332  call  2024-01-01 00:00:00.000000000      0.09     NaN
# 1   2    11458  text  2024-01-01 00:06:30.969774244       NaN    39.0
# 2   3    11777  text  2024-01-01 00:13:01.939548488       NaN    36.0
# 3   4    10682  call  2024-01-01 00:19:32.909322733      1.53     NaN
# 4   5    12742  call  2024-01-01 00:26:03.879096977      4.84     NaN

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ### 1.2 Exploración de la estructura de los datasets
#
# **🎯 Objetivo:**
# Conocer la **estructura de cada dataset**, revisar cuántas filas y columnas tienen, identificar los **tipos de datos** de cada columna y detectar posibles **inconsistencias o valores nulos** antes de iniciar el análisis.
#
# **Instrucciones:**
# - Revisa el **número de filas y columnas** de cada dataset usando `.shape`.
# - Usa `.info()` en cada DataFrame para obtener un **resumen completo** de columnas, tipos de datos y valores no nulos.

# %%
# revisar el número de filas y columnas de cada dataset
print("plans", plans.shape)
print("users", users.shape)
print("usage", usage.shape)
# Out:
# plans (2, 8)
# users (4000, 8)
# usage (40000, 6)

# %%
# inspección de plans con .info()
plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plan_name          2 non-null      object
#  1   messages_included  2 non-null      int64
#  2   gb_per_month       2 non-null      int64
#  3   minutes_included   2 non-null      int64
#  4   usd_monthly_pay    2 non-null      int64
#  5   usd_per_gb         2 non-null      float64
#  6   usd_per_message    2 non-null      float64
#  7   usd_per_minute     2 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 256.0+ bytes

# %%
# inspección de users con .info()
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     4000 non-null   int64
#  1   first_name  4000 non-null   object
#  2   last_name   4000 non-null   object
#  3   age         4000 non-null   int64
#  4   city        3531 non-null   object
#  5   reg_date    4000 non-null   object
#  6   plan        4000 non-null   object
#  7   churn_date  466 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 250.1+ KB

# %%
# inspección de usage con .info()
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        40000 non-null  int64
#  1   user_id   40000 non-null  int64
#  2   type      40000 non-null  object
#  3   date      39950 non-null  object
#  4   duration  17924 non-null  float64
#  5   length    22104 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Identificación de problemas de calidad de datos
#
# ### 2.1 Revisión de valores nulos
#
# **🎯 Objetivo:**
# Detectar la presencia y magnitud de valores faltantes para evaluar si afectan el análisis o requieren imputación/eliminación.
#
# **Instrucciones:**
# - Cuenta valores nulos por columna para cada dataset.
# - Calcula la proporción de nulos por columna para cada dataset.
#
# El dataset `plans` solamente tiene 2 renglones y se puede observar que no tiene ausentes, por ello no necesita exploración adicional.
#
# <br>
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa `.isna().sum()` para contar valores nulos y usa `.isna().mean()` para calcular la proporción.

# %%
# cantidad de nulos para users
print(users.isna().sum())# Cantidad de valores nulos)
print(users.isna().mean())# Proporción de valores nulos)
# Out:
# user_id          0
# first_name       0
# last_name        0
# age              0
# city           469
# reg_date         0
# plan             0
# churn_date    3534
# dtype: int64
# user_id       0.00000
# first_name    0.00000
# last_name     0.00000
# age           0.00000
# city          0.11725
# reg_date      0.00000
# plan          0.00000
# churn_date    0.88350
# dtype: float64

# %%
# cantidad de nulos para usage
print(usage.isna().sum())
print(usage.isna().mean())
# Out:
# id              0
# user_id         0
# type            0
# date           50
# duration    22076
# length      17896
# dtype: int64
# id          0.00000
# user_id     0.00000
# type        0.00000
# date        0.00125
# duration    0.55190
# length      0.44740
# dtype: float64

# %% [markdown]
# ✍️ **Comentario**: Haz doble clic en este bloque y escribe tu diagnóstico al final del bloque. Incluye qué ves y que acción recomendarías para cada caso.
#
# 💡 **Nota:** Justifica tus decisiones brevemente (1 línea por caso).
# * Hint:
#  - Si una columna tiene **más del 80–90% de nulos**, normalmente se **ignora o elimina**.
#  - Se elimina, con capa, la tecnica que deja los datos correctos solamente para poder trabajar con los datos correctos que si aporten valor al análisis.
#  - Si tiene **entre 5% y 30%**, generalmente se **investiga para imputar o dejar como nulos**.
#  - Siempre es importante investigar un poco sin importar el rango de datos incorrectos, para poder tomar la decisión correcta en cuanto a imputar o dejar como datos nulos, ya que si son pocos datos se pueden imputar al no tener mucho impacto en el análsis, pero si son muchos datos es mejor dejarlos como parte del análisis porque deben de tener una razon de ser o hacen parte de un grupo que haya que profundizar o corregir.
#  - Si es **menor al 5%**, suele ser un caso simple de imputación o dejar como nulos.
#  Si es correcto, en la gran mayoría de los casos, pero siempre es importante revisarlos a detalle para llegar a esta conlcusión y trabajar con los mejores datos posbiles.
#  ---
#
# **Valores nulos**
# - ¿Qué columnas tienen valores faltantes y en qué proporción?
# - 1.churn_date tiene casi un 88% de nulos. 2.Duration y length tienen muchos nulos. 3.Tiene ~11.7% de nulos. 4."date" tiene solo 0.1% de nulos.
# - Indica qué harías: ¿imputar, eliminar, ignorar?
# - 1. Ignorar los nulos significan clientes activos. No se imputaría, ni eliminaría en esta categoría churn_date, simplemente se trabajaría con ellos como están.
#   2. duration y length, los ignoraría. Son MAR por diseño del dato.
#   3. city, eliminaría los nulos. Por el impacto que tiene 11.7% no es tan relevante como el 89.3% en contraste de datos.
#   4. date, los imputaría. Las fechas nulas solo darían malos resultados en el analisis del data frame.

# %% [markdown]
# ### 2.2 Detección de valores inválidos y sentinels
#
# 🎯 **Objetivo:**
# Identificar sentinels: valores que no deberían estar en el dataset.
#
# **Instrucciones:**
# - Explora las columnas numéricas con **un resumen estadístico** y describe brevemente que encontraste.
# - Explora las columnas categóricas **relevantes**, revisando sus valores únicos y describe brevemente que encontraste.
#
#
# El dataset `plans` solamente tiene 2 renglones, por ello no necesita exploración adicional.

# %%
# explorar columnas numéricas de users
users.describe()
# Out:
#             user_id          age
# count   4000.000000  4000.000000
# mean   11999.500000    33.739750
# std     1154.844867   123.232257
# min    10000.000000  -999.000000
# 25%    10999.750000    32.000000
# 50%    11999.500000    47.000000
# 75%    12999.250000    63.000000
# max    13999.000000    79.000000

# %% [markdown]
# - La columna `user_id` ... hay 4000 usuarios, con una media de 11999.
# - La columna `age` ... hay 4000 usuarios con una media de edad de 33 años, pero hay un dato de age -999 eso quiere decir que es un valor nulo por revisar.

# %%
# explorar columnas numéricas de usage
usage.describe()
# Out:
#                 id       user_id      duration        length
# count  40000.00000  40000.000000  17924.000000  22104.000000
# mean   20000.50000  12002.405975      5.202237     52.127398
# std    11547.14972   1157.279564      6.842701     56.611183
# min        1.00000  10000.000000      0.000000      0.000000
# 25%    10000.75000  10996.000000      1.437500     37.000000
# 50%    20000.50000  12013.000000      3.500000     50.000000
# 75%    30000.25000  13005.000000      6.990000     64.000000
# max    40000.00000  13999.000000    120.000000   1490.000000

# %% [markdown]
# - Las columnas `id` y `user_id`... hay 4000 usuarios, con una media de 20000 usarios con id y 12002 con user_id eso quiere decir que el registro tiene algunos datos nulos.
# - Las columnas ... duration tiene un total de 17924 datos de duracion y un length de 22104 datos de longitud.

# %%
# explorar columnas categóricas de users

city_user = users["city"].value_counts()
display(city_user)

plan_user = users["plan"].value_counts()
display(plan_user)
# Out:
# Bogotá      808
# CDMX        730
# Medellín    616
# GDL         450
# Cali        424
# MTY         407
# ?            96
# Name: city, dtype: int64
# Basico     2595
# Premium    1405
# Name: plan, dtype: int64

# %% [markdown]
# - La columna `city` tiene categoria información de ciudad con 96 y la ciudad es "?". Nulos por revisar.
# - La columna `plan` tiene categoría basico y premium.

# %%
# explorar columna categórica de usage
type_user = usage['type'].value_counts()
type_user # completa el código
# Out:
# text    22092
# call    17908
# Name: type, dtype: int64

# %% [markdown]
# - La columna `type` tiene columnas text y call como categorías.

# %% [markdown]
# ---
# ✍️ **Comentario**: El resultado muestra 39,950 registros en 2024 (los 50 nulos no aparecen porque no tienen año)
#
# **Valores inválidos o sentinels**
# - ¿En qué columnas encontraste valores inválidos o sentinels?  Encontré en Age, en City y en reg_date.
# - ¿Qué acción tomarías? Toca formatear fechas y detectar años fuera de rango que indiquen errores de captura, convertir las columnas de fecha a tipo fecha y asegurarse de que el codigo sea a prueba de errores.

# %% [markdown]
# ### 2.3 Revisión y estandarización de fechas
#
# **🎯 Objetivo:**
# Asegurar que las columnas de fecha estén correctamente formateadas y detectar años fuera de rango que indiquen errores de captura.
#
# **Instrucciones:**
# - Convierte las columnas de fecha a tipo fecha y asegurate de que el código sea a prueba de errores.
# - Revisa cuántas veces aparece cada año.
# - Identifica fechas imposibles (ej. años futuros o negativos).
#
# Toma en cuenta que tenemos datos registrados hasta el año 2024.

# %%
# Convertir a fecha la columna `reg_date` de users
users["reg_date"] = pd.to_datetime(users["reg_date"])

# %%
# Convertir a fecha la columna `date` de usage
usage["date"] = pd.to_datetime(usage["date"])# completa el código

# %%
# Revisar los años presentes en `reg_date` de users
users["reg_date"].dt.year.value_counts()
# Out:
# 2024    1330
# 2023    1316
# 2022    1314
# 2026      40
# Name: reg_date, dtype: int64

# %% [markdown]
# En `reg_date`, veo que hay datos mas alla del 2024 que hasta donde pide el proyecto revisar datos, entonces el 2026 son datos no requeridos.

# %%
# Revisar los años presentes en `date` de usage
usage["date"].dt.year.value_counts()
# Out:
# 2024.0    39950
# Name: date, dtype: int64

# %% [markdown]
# En `date`, veo que en 2024 hay 39950 datos presentes en usage.
# Basaremos el análisis en estas fechas.

# %% [markdown]
# ✍️ **Comentario**: hay datos correctos pero hay 40 datos incorrectos
#
# **Fechas fuera de rango**
# - ¿Aparecen años imposibles? Si hay años muy nuevos que no son necesarios o requeridos por el proyecto solicitado, el 2026
# - ¿Qué harías con ellas? Imputaría los datos no requeridos para trabajar con los correctos.

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Limpieza básica de datos
#
# ### 3.1 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Aplicar reglas de limpieza para reemplazar valores sentinels y corregir fechas imposibles.
#
# **Instrucciones:**
# - En `age`, reemplaza el sentinel **-999** con la mediana.
# - En `city`, reemplaza el sentinel `"?"` por valores nulos (`pd.NA`).
# - Marca como nulas (`pd.NA`) las fechas fuera de rango.

# %%
# Reemplazar -999 por la mediana de age

age_mediana = users["age"].median()
users["age"] = users["age"].replace(-999, age_mediana)


# Verificar cambios
users['age'].describe()
# Out:
# count    4000.000000
# mean       48.122250
# std        17.690408
# min        18.000000
# 25%        33.000000
# 50%        47.000000
# 75%        63.000000
# max        79.000000
# Name: age, dtype: float64

# %%
# Reemplazar ? por NA en city
users["city"] = users["city"].replace("?", pd.NA)

# Verificar cambios
users["city"].describe()
# Out:
# count       3435
# unique         6
# top       Bogotá
# freq         808
# Name: city, dtype: object

# %%
# Marcar fechas futuras como NA para reg_date
users.loc[users["reg_date"].dt.year > 2024, "reg_date"] = pd.NaT

# Verificar cambios
users["reg_date"].describe()
# Out:
# count                              3960
# unique                             3960
# top       2024-06-27 06:08:22.325581392
# freq                                  1
# first               2022-01-01 00:00:00
# last                2024-12-31 00:00:00
# Name: reg_date, dtype: object

# %% [markdown]
# ### 3.2 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Decidir qué hacer con los valores nulos según su proporción y relevancia.
#
# **Instrucciones:**
# - Verifica si los nulos en `duration` y `length` son **MAR**(Missing At Random) revisando si dependen de la columna `type`.
#   Si confirmas que son MAR, **déjalos como nulos** y justifica la decisión.

# %%
# Verificación MAR en usage (Missing At Random) para duration
usage.groupby("type")["duration"].apply(lambda x: x.isna().sum())
# Out:
# type
# call        0
# text    22076
# Name: duration, dtype: int64

# %%
# Verificación MAR en usage (Missing At Random) para length
usage.groupby("type")["length"].apply(lambda x: x.isna().sum())
# Out:
# type
# call    17896
# text        0
# Name: length, dtype: int64

# %% [markdown]
# count: 3960 → significa que los 40 registros del año 2026 fueron marcados como nulos (4000 - 40 = 3960 ✅),last: 2024-12-31 → ya no hay fechas futuras ✅, los nulos en text y en call de ambas formulas han demostrado que se han limpiado. ✅  `duration` y `length`

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Summary statistics de uso por usuario
#
#
# ### 4.1 Agrupación por comportamiento de uso
#
# 🎯**Objetivo**: Resumir las variables clave de la tabla `usage` **por usuario**, creando métricas que representen su comportamiento real de uso histórico.
#
# **Instrucciones:**:
# 1. Construye una tabla agregada de `usage` por `user_id` que incluya:
# - número total de mensajes
# - número total de llamadas
# - total de minutos de llamadas
#
# 2. Renombra las columnas para que tengan nombres claros:
# - `cant_mensajes`
# - `cant_llamadas`
# - `cant_minutos_llamada`
# 3. Combina esta tabla con `users`.

# %%
# Columnas auxiliares
usage["is_text"] = (usage["type"] == "text").astype(int) #conocer el total de mensajes
usage["is_call"] = (usage["type"] == "call").astype(int) #conocer el total de llamadas


# Agrupar información por usuario

usage_agg = usage.groupby("user_id").agg({"is_text":"sum","is_call":"sum","duration":"sum"}).reset_index()

# observar resultado
usage_agg.head(3)
# Out:
#    user_id  is_text  is_call  duration
# 0    10000        7        3     23.70
# 1    10001        5       10     33.18
# 2    10002        5        2     10.74

# %%
# Renombrar columnas
usage_agg = usage_agg.rename(columns={"is_text":"cant_mensajes","is_call":"cant_llamadas","duration":"cant_minutos_llamada"})

# observar resultado
usage_agg.head(3)
# Out:
#    user_id  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0    10000              7              3                 23.70
# 1    10001              5             10                 33.18
# 2    10002              5              2                 10.74

# %%
# Combinar la tabla agregada con el dataset de usuarios
user_profile = pd.merge(
    users,
    usage_agg,
    on = "user_id",
    how = "inner"

)
user_profile.head(5)
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0   Basico        NaN              7              3                 23.70
# 1   Basico        NaN              5             10                 33.18
# 2   Basico        NaN              5              2                 10.74
# 3  Premium        NaN             11              3                  8.99
# 4   Basico        NaN              4              3                  8.01

# %% [markdown]
# ### 4.2 4.2 Resumen estadístico por usuario durante el 2024
#
# 🎯 **Objetivo:** Analizar las columnas numéricas y categóricas de los usuarios, para identificar rangos, valores extremos y distribución de los datos antes de continuar con el análisis.
#
# **Instrucciones:**
# 1. Para las columnas **numéricas** relevantes, obtén un resumen estadístico (media, mediana, mínimo, máximo, etc.).
# 2. Para la columna **categórica** `plan`, revisa la distribución en **porcentajes** de cada categoría.

# %%
# Resumen estadístico de las columnas numéricas
user_profile.describe()
# Out:
#             user_id          age  cant_mensajes  cant_llamadas  \
# count   3999.000000  3999.000000    3999.000000    3999.000000
# mean   11999.729432    48.124531       5.524381       4.478120
# std     1154.898108    17.692032       2.358416       2.144238
# min    10000.000000    18.000000       0.000000       0.000000
# 25%    10999.500000    33.000000       4.000000       3.000000
# 50%    12000.000000    47.000000       5.000000       4.000000
# 75%    12999.500000    63.000000       7.000000       6.000000
# max    13999.000000    79.000000      17.000000      15.000000
#
#        cant_minutos_llamada
# count           3999.000000
# mean              23.317054
# std               18.168095
# min                0.000000
# 25%               11.120000
# 50%               19.780000
# 75%               31.415000
# max              155.690000

# %%
# Distribución porcentual del tipo de plan
user_profile["plan"].value_counts(normalize=True) * 100
# Out:
# Basico     64.866217
# Premium    35.133783
# Name: plan, dtype: float64

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Visualización de distribuciones (uso y clientes) y outliers
#
#
# ### 5.1 Visualización de Distribuciones
#
# 🎯 **Objetivo:**
# Entender visualmente cómo se comportan las variables clave tanto de **uso** como de **clientes**, observar si existen diferencias según el tipo de plan, y analizar la **forma de la distribución**.
#
# **Instrucciones:**
# Graficar **histogramas** para las siguientes columnas:
# - `age` (edad de los usuarios)
# - `cant_mensajes`
# - `cant_llamadas`
# - `total_minutos_llamada`
#
# Después de cada gráfico, escribe un **insight** respecto al plan y la variable, por ejemplo:
# - "Dentro del plan Premium, hay mayor proporción de..."
# - "Los usuarios Básico tienden a hacer ... llamadas y enviar ... mensajes."  o "No existe algún patrón."
# - ¿Qué tipo de distribución tiene ? (simétrica, sesgada a la derecha o a la izquierda)
#
# **Hint**
# Para cada histograma,
# - Usa `hue='plan'` para ver cómo varían las distribuciones según el plan (Básico o Premium).
# - Usa `palette=['skyblue','green']`
# - Agrega título y etiquetas

# %%
# Histograma para visualizar la edad (age)
sns.histplot(user_profile,x="age",hue="plan",palette=['skyblue', 'green'])
plt.xlabel("Edad")
plt.ylabel("Cantidad de Usuarios")
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución simétrica, la edad de 50 y 75-80 tienen mejores paquetes relación cantidad frente a los otros y los de 20-30 tienen cantidad de usuarios pero mas planes basicos que premium. Las personas de la edad 40 y 60 comparten similitud en tipo plan y cantidad de usuarios.

# %%
# Histograma para visualizar la cant_mensajes
sns.histplot(user_profile,x="cant_mensajes",hue="plan",palette=['skyblue', 'green'])
plt.xlabel("Cantidad de Mensajes")
plt.ylabel("Cantidad de Usuarios")
# Out:
# Text(0, 0.5, 'Cantidad de Usuarios')

# %% [markdown]
# 💡Insights:
# - 1.El grafico es sesgado a la derecha.
# - 2. Domina el plan básico entre los que envian pocos mensajes:
#      Basico 64.87% Premium    35.13%. y en los que envian muchos se encuentra un 50%       de distribución entre basico y premium. Los que envian muchos comparten el 50%        de distrbución entre básico y premium.
#   3. Entre 2.5 y 6.0 comparten similitud en cantidad de mensajes y cantidad de usuarios.

# %%
# Histograma para visualizar la cant_llamadas
sns.histplot(user_profile,x="cant_llamadas",hue="plan",palette=['skyblue', 'green'])
plt.xlabel("Cantidad de Llamadas")
plt.ylabel("Cantidad de Usuarios")
# Out:
# Text(0, 0.5, 'Cantidad de Usuarios')

# %% [markdown]
# 💡Insights:
# - Distribución sesgada hacia la derecha.
# - Entre mas de 500 usuarios hacen por lo regular 4 llamadas. Dominando el plan basico en general, entre mas llamadas mas planes premium se ven dominando la tabla. Entre 2 llamdas y 6 llamadas comparten similitudes.

# %%
# Histograma para visualizar la cant_minutos_llamada
sns.histplot(user_profile,x="cant_minutos_llamada",hue="plan",palette=['skyblue', 'green'])
plt.xlabel("Cantidad de minutos por llamada")
plt.ylabel("Cantidad de Usuarios")
# Out:
# Text(0, 0.5, 'Cantidad de Usuarios')

# %% [markdown]
# 💡Insights:
# - Distribución sesgada hacia la derecha. Dominando el 65% de los datos con el plan Básico. Entre 15 y 17 llamadas comparten similitud en datos de cantidad de usuarios y plan basico. Entre más cantida de minutos por llamada mas planes premium dominan la tabla en poca cantidad de usuarios. La mayoría de usuarios mantienen el plan basico con 65%.

# %% [markdown]
# ### 5.2 Identificación de Outliers
#
# 🎯 **Objetivo:**
# Detectar valores extremos en las variables clave de **uso** y **clientes** que podrían afectar el análisis, y decidir si requieren limpieza o revisión adicional.
#
# **Instrucciones:**
# - Usa **boxplots** para identificar visualmente outliers en las siguientes columnas:
#   - `age`
#   - `cant_mensajes`
#   - `cant_llamadas`
#   - `total_minutos_llamada`
# - Crea un **for** para generar los 4 boxplots automáticamente.
# <br>
#
# - Después de crear los gráfico, responde si **existen o no outliers** en las variables.
# - Si hay outliers, crea otro bucle para calcular los límites de esas columnas usando el **método IQR** y decide qué hacer con ellos.
#   - Si solamente hay outliers de un solo lado, no es necesario calcular ambos límites.
#
# **Hint:**
# - Dentro del bucle, usa `plt.title(f'Boxplot: {col}')` para que el título cambie acorde a la columna.

# %%
# Visualizando usando BoxPlot 
columnas_numericas = ['age', 'cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in columnas_numericas:
    sns.boxplot(data=user_profile, y=col)
    plt.title(f'Boxplot: {col}')
    plt.show()

# %% [markdown]
# 💡Insights:
# - Age: no presenta outliers.
# - cant_mensajes: 12.5 a 17.5 cantidad de mensajes, son los datos outliers.
# - cant_llamadas: 11 a 15 cantidad de llamadas, son los datos outliers.
# - cant_minutos_llamada: 60 a 160 son la cantidad de llamadas, en datos outliers.

# %%
# Calcular límites con el método IQR
Q1 = user_profile[columnas_numericas].quantile(0.25)
Q3 = user_profile[columnas_numericas].quantile(0.75)
IQR = Q3 - Q1
Limite_inferior = Q1 - 1.5*IQR
Limite_superior = Q3 + 1.5*IQR
columnas_limites = ['cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']




for col in columnas_limites:
    sns.boxplot(data=user_profile, y=col)
    plt.title(f'Boxplot: {col}')
    plt.axhline(y=Limite_superior[col], color="red", linestyle="--")
    plt.show()

# %%
# Revisa los limites superiores y el max, para tomar la decisión de mantener los outliers o no
user_profile[columnas_limites].describe()
# Out:
#        cant_mensajes  cant_llamadas  cant_minutos_llamada
# count    3999.000000    3999.000000           3999.000000
# mean        5.524381       4.478120             23.317054
# std         2.358416       2.144238             18.168095
# min         0.000000       0.000000              0.000000
# 25%         4.000000       3.000000             11.120000
# 50%         5.000000       4.000000             19.780000
# 75%         7.000000       6.000000             31.415000
# max        17.000000      15.000000            155.690000

# %% [markdown]
# 💡Insights:
# - cant_mensajes: No mantener outliers. Son 11 mensajes y son 17 mensajes maximos.
# - cant_llamadas: No mantener outliers. Son 11 llamadas el Limite superior y tienen 15 llamadas.
# - cant_minutos_llamada: Límite superior IQR es de 61.50 y el máximo es de 155.69 en la tabla de datos. No mantenter outliers, por datos que entorpecen el analisis de los datos.

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Segmentación de Clientes
#
# ### 6.1 Segmentación de Clientes Por Uso
#
# 🎯 **Objetivo:** Clasificar a cada usuario en un grupo de uso (Bajo uso, Uso medio, Alto uso) basándose en la cantidad de llamadas y mensajes registrados.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_uso` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones de llamadas y mensajes y asigna:
#   - `'Bajo uso'` cuando llamadas < 5 y mensajes < 5
#   - `'Uso medio'` cuando llamadas < 10 y mensajes < 10
#   - `'Alto uso'` para el resto de casos

# %%
# Crear columna grupo_uso

import numpy as np
condiciones = [
    (user_profile["cant_llamadas"]<5) & (user_profile["cant_mensajes"] < 5),
    (user_profile["cant_llamadas"]<10) & (user_profile["cant_mensajes"] < 10),
]
etiquetas = ["Bajo uso", "Uso medio"]
user_profile["grupo_uso"] = np.select(condiciones, etiquetas, default="Alto uso")

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada  \
# 0   Basico        NaN              7              3                 23.70
# 1   Basico        NaN              5             10                 33.18
# 2   Basico        NaN              5              2                 10.74
# 3  Premium        NaN             11              3                  8.99
# 4   Basico        NaN              4              3                  8.01
#
#    grupo_uso
# 0  Uso medio
# 1   Alto uso
# ...

# %% [markdown]
# ### 6.2 Segmentación de Clientes Por Edad
#
# 🎯 **Objetivo:**: Clasificar a cada usuario en un grupo por **edad**.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_edad` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones y asigna:
#   - `'Joven'` cuando age < 30
#   - `'Adulto'` cuando age < 60
#   - `'Adulto Mayor'` para el resto de casos

# %%
# Crear columna grupo_edad
import numpy as np
condiciones = [
    (user_profile["age"]<30),
    (user_profile["age"]<60),
]
etiquetas = ["Joven", "Adulto"]
user_profile["grupo_edad"] = np.select(condiciones, etiquetas, default="Adulto Mayor")

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada  \
# 0   Basico        NaN              7              3                 23.70
# 1   Basico        NaN              5             10                 33.18
# 2   Basico        NaN              5              2                 10.74
# 3  Premium        NaN             11              3                  8.99
# 4   Basico        NaN              4              3                  8.01
#
#    grupo_uso    grupo_edad
# ...

# %% [markdown]
# ### 6.3 Visualización de la Segmentación de Clientes
#
# 🎯 **Objetivo:** Visualizar la distribución de los usuarios según los grupos creados: **grupo_uso** y **grupo_edad**.
#
# **Instrucciones:**
# - Crea dos gráficos para las variables categóricas `grupo_uso` y `grupo_edad`.
# - Agrega título y etiquetas a los ejes en cada gráfico.

# %%
# Visualización de los segmentos por uso
sns.countplot(data=user_profile, x="grupo_uso", hue="grupo_edad", palette=['skyblue', 'green','red'])

plt.show()

# %%
# Visualización de los segmentos por edad
sns.countplot(data=user_profile, x="grupo_edad", hue="grupo_uso", palette=['skyblue', 'green','red'])

plt.show()

# %% [markdown]
# ---
# ## 🧩Paso 7: Insight Ejecutivo para Stakeholders
#
# 🎯 **Objetivo:** Traducir los hallazgos del análisis en conclusiones accionables para el negocio, enfocadas en segmentación, patrones de uso y oportunidades comerciales.
#
# **Preguntas a responder:**
# - ¿Qué problemas tenían originalmemte los datos?¿Qué porcentaje, o cantidad de filas, de esa columna representaban?
#     1) En age: hay 4000 usuarios con una media de edad de 33 años, pero hay un dato de age -999 eso quiere decir que es un valor nulo por revisar.
#     2) En City: tiene categoria información de ciudad con 96 y la ciudad es "?". Nulos por revisar.
#     3) En reg_date: 40 registros tenian fechas fuera del rango en 2026.
#     4) En usage: duration tiene un total de 17924 datos de duracion y un length de 22104 datos de longitud, muchos datos para ser mensajes y llamadas,  había un sesgo de datos en este punto.
# - ¿Qué segmentos de clientes identificaste y cómo se comportan según su edad y nivel de uso?
# Uso medio tiene ~1400 usuarios → es el grupo más grande.
# Los de Alto uso tienden a ser Adultos. Pero se van mas los de alto uso, porque no hay un valor para mantenerse con un uso mayor y que mas usuarios quieran seguir usandolo.
#
# El problema: No hay una opción intermedia entre Básico y Premium ($13 de diferencia, 15GB y 500 min más).
# El impacto: Usuarios de uso medio/alto no ven valor suficiente y se van (churn ~11.65%).
# La solución: Un plan intermedio que capture ese segmento "en el medio".
# - ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
#   El segmento de Alto uso, Medio uso y Bajo uso, estos 3 son muy importantes para dar a entender en que parte podemos retener más clientes, como lo sería en el uso alto, donde se ve un gran porcentaje de revenue pero poca retención, y un uso medio del plan básico con 1400 usuarios, donde pueden ver mas retencion o mejoras de plan comenzando con un plan intermedio para despues pasar a un plan premium con promociones y ofertas cada cierto tiempo para mantener a los clientes frecuentes.
# - ¿Qué patrones de uso extremo (outliers) encontraste y qué implican para el negocio?
# cant_minutos_llamada: Usuarios con necesidades específicas que exceden los 100 min del plan Básico → pagan extra → posible insatisfacción → riesgo de churn
# cant_llamadas: Usuarios que simplemente usan más que el promedio → exceden límites → cobro extra
# cant_mensajes: Usuarios que exceden límites → cobro extra → más revenue para ConnectaTel
# - ¿Qué recomendaciones harías para mejorar la oferta actual de planes o crear nuevos planes basados en los segmentos y patrones detectados?
# 📉 Pocos usuarios de Alto uso, pero generan desproporcionadamente más ingresos → el sesgo a la derecha lo confirma
# 🎯 Un plan intermedio actúa como escalón de valor: el usuario prueba
#
# ✍️ **análisis ejecutivo:**
# Lo más recomendable es con los outliers, lograr ejercer un programa de 18 dolares en el plan intermedio entre el basico y el premium donde se aumente los valore del basico a tal manera que quede entre medio de los valores ofrecidos en el premium, de esa manera el cliente va probando poco a poco como obtener mas valor pagando un poco más para acercarse la experiencia ultra premium que seria otra categoría despues de la premium existente donde tendría llamadas ilimitadas con un valor total de 30$ para este tipo de outliers que hacen 155 llamadas al mes. De esta manera cubrimos la alta demanda del plan basico y el uso medio del mismo, y tambien mejoramos demanda del plan premium en Alto uso.

# %% [markdown]
# ### Análisis ejecutivo
#
# ⚠️ **Problemas detectados en los datos**
# Durante el proceso de exploración y limpieza se identificaron varios problemas de calidad:
#
# Se detectó un valor inválido en la columna age con valor -999, equivalente a un registro erróneo o faltante.
# La columna city contenía registros con el valor "?", representando ciudades desconocidas.
# Se encontraron aproximadamente 40 registros con fechas fuera del rango esperado en reg_date, correspondientes al año 2026.
# Se identificaron valores faltantes en variables de uso (mensajes, llamadas y minutos), los cuales fueron tratados para evitar sesgos en el análisis.
# Se detectaron valores atípicos en cantidad de mensajes, llamadas y minutos consumidos.
#
#
# 🔍 **Segmentos por Edad**
# La mayor parte de los clientes pertenece al segmento Adulto (30-59 años).
# Los usuarios jóvenes representan una proporción importante de la base de clientes y muestran patrones de consumo estables.
# Los adultos mayores representan el grupo más pequeño dentro de la muestra.
#
#
# 📊 **Segmentos por Nivel de Uso**
# La mayoría de los clientes se concentra en los segmentos de Bajo Uso y Uso Medio.
# Los usuarios con mayor cantidad de llamadas, mensajes y minutos consumidos muestran una mayor presencia en el plan Premium.
# Los clientes del plan Básico dominan la base de usuarios, especialmente entre quienes presentan niveles bajos de consumo.
#
# 📈 Patrones de Consumo Identificados
# Las distribuciones de llamadas, mensajes y minutos presentan una fuerte asimetría positiva (sesgo a la derecha).
# La mayoría de los usuarios utiliza cantidades moderadas de servicios, mientras que un grupo reducido concentra consumos elevados.
# A medida que aumenta el consumo, aumenta también la participación de usuarios con plan Premium.
# Los usuarios de alto consumo representan una oportunidad clara para estrategias de upselling y retención.
#
#
# 💡 **Recomendaciones de Negocio**
# Implementar campañas de migración del plan Básico al Premium para usuarios con consumos cercanos a los límites del plan básico.
# Diseñar promociones específicas para usuarios de Uso Medio, ya que representan el segmento con mayor potencial de crecimiento.
# Mantener monitoreo constante de la calidad de los datos para evitar registros inválidos y valores atípicos que afecten futuros análisis.
# Crear programas de fidelización para usuarios Premium de alto consumo, ya que generan una mayor utilización de los servicios.
#
# 🎯 **Conclusión Final**
#
# El análisis de ConnectaTel permitió identificar patrones claros de comportamiento de los clientes y detectar oportunidades comerciales relevantes. La mayoría de los usuarios pertenece al plan Básico y presenta niveles de consumo bajos o moderados. Sin embargo, se observó que los clientes con mayores niveles de uso tienden a concentrarse en el plan Premium, lo que sugiere una relación directa entre el nivel de consumo y el valor percibido de los servicios avanzados.
#
# Además, la segmentación por edad y nivel de uso permitió identificar grupos de clientes con características diferenciadas, facilitando el diseño de estrategias comerciales más específicas. Finalmente, la limpieza y validación de los datos resultó fundamental para garantizar la confiabilidad del análisis y apoyar la toma de decisiones basada en evidencia.
#
# En conclusión, ConnectaTel tiene una oportunidad importante para incrementar ingresos mediante estrategias de migración al plan Premium, enfocándose especialmente en usuarios de consumo medio y alto que aún permanecen en el plan Básico.

# %% [markdown]
# ---
#
# ## 🧩Paso 8 Cargar tu notebook y README a GitHub
#
# 🎯 **Objetivo:**
# Entregar tu análisis de forma **profesional**, **documentada** y **versionada**, asegurando que cualquier persona pueda revisar, ejecutar y entender tu trabajo.
#
#
#
# ### Opción A : Subir archivos desde la interfaz de GitHub (UI)
#
# 1. Descarga este notebook (`File → Download .ipynb`).
# 2. Entra a tu repositorio en GitHub (por ejemplo `telecom-analysis` o `sprint7-final-project`).
# 3. Sube tu notebook **Add file → Upload files**.
#
# ---
#
# ### Opción B : Guardar directo desde Google Colab
#
# 1. Abre tu notebook en Colab.
# 2. Ve a **File → Save a copy in GitHub**.
# 3. Selecciona el repositorio y la carpeta correcta (ej: `notebooks/`).
# 4. Escribe un mensaje de commit claro, por ejemplo:
#     - `feat: add final ConnectaTel analysis`
#     - `agregar version final: Análisis ConnectaTel`
# 5. Verifica en GitHub que el archivo quedó en el lugar correcto y que el historial de commits se mantenga limpio.
#
# ---
#
# Agrega un archivo `README.md` que describa de forma clara:
# - el objetivo del proyecto,
# - los datasets utilizados,
# - las etapas del análisis realizadas,
# - cómo ejecutar el notebook (por ejemplo, abrirlo en Google Colab),
# - una breve guía de reproducción.
# ---

# %% [markdown]
# Link a repositorio público del proyecto: `LINK a tu repo aquí`
